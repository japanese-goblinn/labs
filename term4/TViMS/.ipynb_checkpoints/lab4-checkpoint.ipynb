# %% [markdown]
# # ЛР 4

# %% [markdown]
# # Интервальные оценки

# %%
from random import uniform
from pprint import pprint
from scipy.stats import t, chi2
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
def Y(x):
    return 2 / (2 + x)

A = -1
B = 5

# %% [markdown]
# Теоретическая плотность распределения

# %%
def f(x):
    if A <= x <= B:
        return 1 / (B - A)
    else:
        return 0

def g(y):
    return f(2 / y - 2) * (2 / y**2)

# %% [markdown]
# Теоретическая функция распределения

# %%
def G(y):
    if y < 2 / 7:
        return 0
    elif y > 2:
        return 1
    else:
        return 1 / 3 * (-(1 / y) + 3.5)

# %% [markdown]
# ## Доверительный интервал для математического ожидания СВ

# %%
arrange = np.arange(0.0, 1.01, 0.01)[1:-1]

# Сформировать выборку из n случайных чисел.
def get_x_values(n):
    X = sorted(round(uniform(0, 1) * (B - A) + A, 4) for _ in range(n))
    x_list = sorted([round(Y(X[i]), 4) for i in range(n)])
    return x_list

# Найти точечную оценку математического ожидания.
def mat_exp(x_list, n):
    return sum(x_list) / n

# Найте точечную оценку дисперсии СВ.
def disp(x_list, n, mx):
     return 1 / (n - 1) * sum((x - mx)**2 for x in x_list)
    
# Найти доверительный интервал для оценки мат ожидания для различных уровней значимости
def get_intervals(n, mx, disp, alpha=None):
    intervals = []
    if alpha is None:
        for i in arrange:
            cof = np.sqrt(disp) * t.ppf(1 - i / 2, n - 1) / np.sqrt(n - 1)
            intervals.append((mx - cof, mx + cof))
        return intervals
    else:
        cof = np.sqrt(disp) * t.ppf(1 - alpha / 2, n - 1) / np.sqrt(n - 1)
        return mx - cof, mx + cof

# %% [markdown]
# Сформировать выборку из 20 случайных чисел.

# %%
n = 20
x_list = get_x_values(n)
print(x_list)
# Out:
# [0.2998, 0.3111, 0.3208, 0.3406, 0.3408, 0.3508, 0.3632, 0.3664, 0.3789, 0.3819, 0.4191, 0.437, 0.4964, 0.5284, 0.5385, 0.6165, 0.6216, 0.771, 1.1009, 1.1217]

# %% [markdown]
# Найти точечную оценку математического ожидания.

# %%
mx = mat_exp(x_list, n)
mx
# Out:
# 0.5052700000000001

# %% [markdown]
# Найте точечную оценку дисперсии СВ.

# %%
known_disp = disp(x_list, n, mx)
known_disp

# %% [markdown]
# Найти доверительный интервал для оценки мат ожидания для различных уровней значимости

# %%
e_intervals = get_intervals(n, mx, known_disp)

# %% [markdown]
# График зависимости велечины доверительного интервала от уровня значимости

# %%
x_plot = arrange[:]
y_plot = [j - i for i, j in e_intervals]
plt.plot(x_plot, y_plot)
plt.show()

# %% [markdown]
# Найти теоретическое значение дисперсии СВ по известной плотности распределения

# %%
t_mx = 0.65
t_dx = 0.15
t_dx
#вбить подсчеты с листика
# Out:
# 0.15

# %% [markdown]
# Найти доверительный интервал для оценки мат ожидания при известной дисперсии для различных уровней значимости

# %%
t_intervals = get_intervals(n, mx, t_dx)

# %% [markdown]
# График зависимости велечины доверительного интервала от уровня значимости

# %%
x_plot = arrange[:]
y_plot = [j - i for i, j in t_intervals]
plt.plot(x_plot, y_plot)
plt.show()

# %% [markdown]
# Сравнить результаты

# %%
x_plot = arrange[:]
y_plot_e = [j - i for i, j in e_intervals]
y_plot_t = [j - i for i, j in t_intervals]
plt.plot(x_plot, y_plot_e)
plt.plot(x_plot, y_plot_t)
plt.show()

# %%
n_list = [30, 50, 70, 100, 150]
mx_list = []
dx_list = []
e_intervals_list = []
t_intervals_list = []
len_intervals_e = []
len_intervals_t = []
for n in n_list:
    print(f"Размер выборки: {n}")
    x_list = get_x_values(n)
    mx_list.append(mat_exp(x_list, n))
    dx_list.append(disp(x_list, n, mx_list[-1]))
    e_intervals_list.append(get_intervals(n, mx_list[-1], dx_list[-1]))
    t_intervals_list.append(get_intervals(n, mx_list[-1], t_dx))
    print(f"Мат ожидание: {mx_list[-1]}")
    print(f"Дисперсия: {dx_list[-1]}")
    x_plot = arrange[:]
    len_intervals_e.append([j - i for i, j in e_intervals_list[-1]])
    len_intervals_t.append([j - i for i, j in t_intervals_list[-1]])
    plt.plot(x_plot, len_intervals_e[-1])
    plt.plot(x_plot, len_intervals_t[-1])
    plt.show()
# Out:
# Размер выборки: 30
# Мат ожидание: 0.6212633333333333
# Дисперсия: 0.11407043136781607
# Размер выборки: 50
# Мат ожидание: 0.6343459999999999
# Дисперсия: 0.17476653804489792
# Размер выборки: 70
# Мат ожидание: 0.7353799999999999
# Дисперсия: 0.19935536423188407
# Размер выборки: 100
# Мат ожидание: 0.6837209999999999
# Дисперсия: 0.1727387331909091
# Размер выборки: 150
# Мат ожидание: 0.6415926666666667
# Дисперсия: 0.13768493370425056

# %% [markdown]
# Графики зависимости величины доверительного интервала от объема выборки

# %%
y_plot_e = []
len_y_plot_e = []
y_plot_t = []
len_y_plot_t = []
for i, n in enumerate(n_list):
    y_plot_e.append(get_intervals(n, mx_list[i], dx_list[i], alpha=0.05))
    left, right = y_plot_e[-1]
    len_y_plot_e.append(right - left)
    y_plot_t.append(get_intervals(n, mx_list[i], t_dx, alpha=0.05))
    left, right = y_plot_t[-1]
    len_y_plot_t.append(right - left)
plt.plot(n_list, len_y_plot_e)
plt.plot(n_list, len_y_plot_t)
plt.legend(('Неизвестная дисперсия', 'Известная дисперсия'))
plt.show()

# %% [markdown]
# ## Доверительный интервал для дисперсии СВ

# %%
# Доверительный интервал для оценки дисперсии для различных уровней значимости
def dx_intervals(x_list, n, mx, alpha=None):
    intervals = []
    disper = disp(x_list, n, mx)
    if alpha is None:
        for i in reversed(arrange):
            left = n * disper / chi2.isf((1 - i) / 2, n - 1)
            right = n * disper / chi2.isf((1 + i) / 2, n - 1)
            intervals.append((left, right))
        return intervals
    else:
        left = n * disper / chi2.isf((1 - alpha) / 2, n - 1)
        right = n * disper / chi2.isf((1 + alpha) / 2, n - 1)
        return left, right

# %% [markdown]
# Сформировать выборку из 20 случайных чисел.

# %%
n = 20
x_list = get_x_values(n)
print(x_list)
# Out:
# [0.2881, 0.2983, 0.3215, 0.3355, 0.3405, 0.3546, 0.3564, 0.4136, 0.4235, 0.425, 0.4408, 0.4444, 0.4685, 0.4988, 0.528, 0.6113, 0.6797, 0.8028, 1.1404, 1.566]

# %% [markdown]
# Найти точечную оценку математического ожидания.

# %%
mx = mat_exp(x_list, n)
mx
# Out:
# 0.5368850000000001

# %% [markdown]
# Найте точечную оценку дисперсии СВ.

# %%
dx = disp(x_list, n, mx)
dx
# Out:
# 0.09971847292105264

# %% [markdown]
# Найти доверительный интервал для оценки дисперсии для различных уровней значимости

# %%
e_intervals = dx_intervals(x_list, n, mx)
# e_intervals

# %% [markdown]
# График зависимости велечины доверительного интервала от уровня значимости

# %%
x_plot = arrange[:]
y_plot = [j - i for i, j in e_intervals]
plt.plot(x_plot, y_plot)
plt.show()

# %% [markdown]
# Найти доверительный интервал для оценки дисперсии для различных уровней значимости

# %%
t_intervals = dx_intervals(x_list, n, t_mx)

# %% [markdown]
# График зависимости велечины доверительного интервала от уровня значимости

# %%
x_plot = arrange[:]
y_plot = [j - i for i, j in t_intervals]
plt.plot(x_plot, y_plot)
plt.show()

# %% [markdown]
# Сравнить результаты

# %%
x_plot = arrange[:]
y_plot_e = [j - i for i, j in e_intervals]
y_plot_t = [j - i for i, j in t_intervals]
plt.plot(x_plot, y_plot_e)
plt.plot(x_plot, y_plot_t)
plt.show()

# %%
n_list = [30, 50, 70, 100, 150]
mx_list = []
dx_list = []
e_intervals_list = []
t_intervals_list = []
len_intervals_e = []
len_intervals_t = []
for n in n_list:
    print(f"Размер выборки: {n}")
    x_list = get_x_values(n)
    mx_list.append(mat_exp(x_list, n))
    dx_list.append(disp(x_list, n, mx_list[-1]))
    e_intervals_list.append(dx_intervals(x_list, n, mx_list[-1]))
    t_intervals_list.append(dx_intervals(x_list, n, t_mx))
    print(f"Мат ожидание: {mx_list[-1]}")
    print(f"Дисперсия: {dx_list[-1]}")
    x_plot = arrange[:]
    len_intervals_e.append([j - i for i, j in e_intervals_list[-1]])
    len_intervals_t.append([j - i for i, j in t_intervals_list[-1]])
    plt.plot(x_plot, len_intervals_e[-1])
    plt.plot(x_plot, len_intervals_t[-1])
    plt.show()
# Out:
# Размер выборки: 30
# Мат ожидание: 0.7605566666666667
# Дисперсия: 0.22492701426436779
# Размер выборки: 50
# Мат ожидание: 0.6514479999999999
# Дисперсия: 0.1583295082612245
# Размер выборки: 70
# Мат ожидание: 0.6122228571428573
# Дисперсия: 0.13358808323809526
# Размер выборки: 100
# Мат ожидание: 0.6322030000000001
# Дисперсия: 0.1589083160515152
# Размер выборки: 150
# Мат ожидание: 0.5778813333333337
# Дисперсия: 0.10431212689753913

# %% [markdown]
# Графики зависимости величины доверительного интервала от объема выборки

# %%
y_plot_e = []
len_y_plot_e = []
y_plot_t = []
len_y_plot_t = []
for i, n in enumerate(n_list):
    y_plot_e.append(dx_intervals(x_list, n, mx_list[i], alpha=0.05))
    left, right = y_plot_e[-1]
    len_y_plot_e.append(right - left)
    y_plot_t.append(dx_intervals(x_list, n, t_mx, alpha=0.05))
    left, right = y_plot_t[-1]
    len_y_plot_t.append(right - left)
plt.plot(n_list, len_y_plot_e)
plt.plot(n_list, len_y_plot_t)
plt.legend(('Неизвестное мат ожидание', 'Известное мат ожидание'))
plt.show()
