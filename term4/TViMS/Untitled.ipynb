# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
Ic12v = [0, 0.12, 0.18, 0.24, 0.26, 0.32, 0.34, 0.37, 0.4, 0.42, 0.44, 0.48, 0.5, 0.52, 0.55, 0.56, 0.57, 0.6, 0.62, 0.64, 0.66, 0.68, 0.74, 0.77, 0.8 ]
Ia12v = [0.94, 0.93, 0.92, 0.91, 0.9, 0.88, 0.86, 0.84, 0.82, 0.8, 0.78, 0.73, 0.7, 0.66, 0.62, 0.54, 0.48, 0.41, 0.37, 0.33, 0.3, 0.28, 0.22, 0.2, 0.18]

delta12v = [round(abs(Ia12v[i] - Ia12v[i-1]), 3) for i in range(1, len(Ia12v[1:]) + 1)]
delta12v
max_el = max(delta12v)
indx = delta12v.index(max_el)
left_delta12v = sorted(delta12v[:indx + 1])
right_delta12v = sorted(delta12v[indx:], reverse=True)
delta12v = left_delta12v + right_delta12v[1:]

# %%
plt.plot(Ic12v, Ia12v)
plt.grid(True)
plt.show()

# %%
plt.plot(Ic12v[:-1], delta12v)
plt.grid(True)
plt.show()
index_el12 = delta12v.index(max(delta12v))
el12 = Ic12v[:-1][index_el12]
el12
# Out:
# 0.55

# %%
Ic14v = [0, 0.06, 0.24, 0.3, 0.34, 0.37, 0.41, 0.45, 0.46, 0.48, 0.5,
         0.52, 0.54, 0.56, 0.58, 0.6, 0.62, 0.64, 0.66, 0.7, 0.72, 0.76, 0.8]
Ia14v = [1.18, 1.16, 1.14, 1.12, 1.1, 1.05, 1.02, 1, 0.98,
         0.94, 0.9, 0.86, 0.8, 0.72, 0.7, 0.57, 0.5, 0.46, 0.4, 0.34, 0.3, 0.27, 0.24]
delta14v = [abs(Ia14v[i] - Ia14v[i-1]) for i in range(1, len(Ia14v[1:]) + 1)]
max_el = max(delta14v)
indx = delta14v.index(max_el)
left_delta14v = sorted(delta14v[:indx + 1])
right_delta14v = sorted(delta14v[indx:], reverse=True)
delta14v = left_delta14v + right_delta14v[1:]

# %%
plt.plot(Ic14v, Ia14v)
plt.grid(True)
plt.show()

# %%
plt.plot(Ic14v[:-1], delta14v)
plt.grid(True)
plt.show()
index_el14 = delta14v.index(max(delta14v))
el14 = Ic14v[:-1][index_el14]
el14
# Out:
# 0.58

# %%
Ic16v = [0, 0.24, 0.3, 0.36, 0.41, 0.43, 0.44, 0.48, 0.49,
         0.5, 0.52, 0.54, 0.56, 0.58, 0.6, 0.62, 0.64, 0.66, 0.68, 0.7, 0.72, 0.76, 0.8]

Ia16v = [1.4, 1.38, 1.36, 1.32, 1.28, 1.26, 1.24, 1.2, 1.18,
         1.14, 1.1, 1.04, 0.96, 0.85, 0.76, 0.66, 0.56, 0.51, 0.46, 0.42, 0.4, 0.36, 0.32]

delta16v = [abs(Ia16v[i] - Ia16v[i-1]) for i in range(1, len(Ia16v[1:]) + 1)]
max_el = max(delta16v)
indx = delta16v.index(max_el)
left_delta16v = sorted(delta16v[:indx + 1])
right_delta16v = sorted(delta16v[indx:], reverse=True)
delta16v = left_delta16v + right_delta16v[1:]

# %%
plt.plot(Ic16v, Ia16v)
plt.grid(True)
plt.show()

# %%
plt.plot(Ic16v[:-1], delta16v)
plt.grid(True)
plt.show()
index_el16 = delta16v.index(max(delta16v))
el16 = Ic16v[:-1][index_el16]
el16
# Out:
# 0.56
